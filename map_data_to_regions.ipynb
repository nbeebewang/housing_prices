# %%
import sys
sys.path.append("/anaconda/lib/python2.7/site-packages")


import pandas as pd
import numpy as np
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
import string
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import shapefile
from sklearn.neighbors import KNeighborsClassifier as KNN

# %% [markdown]
# ## Code to map lat/long to regions

# %%
########### Example use of this code:

# path_to_shape_file = '/Users/nbw/Dropbox/CS_109_Project/crime_UNFORMATTED/nypp_16b/nypd_pres'
# regions_dict = generate_regions_to_points_dict(path_to_shape_file, "Precinct")
# get_region_from_latlong_and_shapefile(40.768814, -73.931085, regions_dict)
# #	--> returns 114

#################################################################################################
####### Inputs:
#######     - path to shapefile
#######		- name of the attribute we want as our name of each region
####### Returns:
#######		- dict mapping region names to shape polygons 

def generate_regions_to_points_dict(shapefile_path, region_attribute_name):
    sf = shapefile.Reader(shapefile_path)
    shapes = sf.shapes()
    records = sf.records()
    fields = sf.fields
    
    # Make sure region_attribute_name exists in the shapefile
    found = False
    for i in range(1, len(fields)):
        if fields[i][0] == region_attribute_name:
            attribute_key = i-1
            found = True
    if not found:
        print "Region attribute not found. Available attributes:"
        for i in range(1, len(fields)):
            print str(fields[i][0]) + "\t",
        return     

    
    regions_to_points_dict = {}
    for i in range(len(records)):
        regions_to_points_dict[records[i][attribute_key]] = shapes[i].points
    return regions_to_points_dict
 



#################################################################################################
####### Code from: http://www.ariel.com.au/a/python-point-int-poly.html
####### Inputs:
####### 	- x value
#######		- y value
#######		- polygon: list of (x,y) pairs corresponding to the perimeter/corners of a polygon
####### Returns: true if x,y is in the specified polygon

def point_inside_polygon(x,y,poly):

    n = len(poly)
    inside =False

    p1x,p1y = poly[0]
    for i in range(n+1):
        p2x,p2y = poly[i % n]
        if y > min(p1y,p2y):
            if y <= max(p1y,p2y):
                if x <= max(p1x,p2x):
                    if p1y != p2y:
                        xinters = (y-p1y)*(p2x-p1x)/(p2y-p1y)+p1x
                    if p1x == p2x or x <= xinters:
                        inside = not inside
        p1x,p1y = p2x,p2y

    return inside




#################################################################################################
####### Inputs:
#######     - latitude
#######		- longitude 
#######     - regions_to_points_dict - keys are region names, values are lists of points outlining the region
#######								- see "generate_regions_to_points_dict" method to create one of these dicts
####### Returns:
#######		- region the latitude,longitude input falls inside 

def get_region_from_latlong_and_shapefile(latitude, longitude, regions_to_points_dict, print_errors = True):
    for key in regions_to_points_dict.keys():
        if point_inside_polygon(longitude, latitude, regions_to_points_dict[key]):
            return key
    if print_errors:
        print "region not found"
    return

# %%
# shapefiles:

path_to_neighborhood_shape_file = '/Users/nbw/Dropbox/CS_109_Project/ZillowNeighborhoods-NY/ZillowNeighborhoods-NY'
neighborhood_dict = generate_regions_to_points_dict(path_to_neighborhood_shape_file, 'NAME')

path_to_schooldistrict_shape_file = '/Users/nbw/Dropbox/CS_109_Project/test_scores/plswork/plswork'
school_district_dict = generate_regions_to_points_dict(path_to_schooldistrict_shape_file, 'SchoolDist')

path_to_precincts_shape_file = '/Users/nbw/Dropbox/CS_109_Project/crime_UNFORMATTED/nypp_16b/nypd_pres'
precincts_dict = generate_regions_to_points_dict(path_to_precincts_shape_file, 'Precinct')

# %%
# zillow data
df = pd.read_csv("/Users/nbw/Dropbox/CS_109_Project/manhattan_data_full.csv")

# drop rows without long/lat (5 rows)
df = df[np.isfinite(df['longitude'])]
df = df[np.isfinite(df['latitude'])]

# %%
df.index.values.shape
# Out:
# (22792,)

# %%
df['latitude'].iloc[1]
# Out:
# 40.724420000000002

# %%
df['longitude'].iloc[1]
# Out:
# -73.980199999999996

# %%
df.index.values
# Out:
# array([    0,     1,     2, ..., 22793, 22794, 22795])

# %%
df["neighborhood"] = None
for i in df.index:
    df.set_value(i, 'neighborhood', get_region_from_latlong_and_shapefile(df['latitude'].loc[i] , df['longitude'].loc[i] , neighborhood_dict, print_errors=False))
    
# fill missing values using sklearn's knn functions
unknown = df[df["neighborhood"] != df["neighborhood"]]
known = df[df["neighborhood"] == df["neighborhood"]]

train_x_matrix = known[["latitude", "longitude"]].values
train_y_matrix = known["neighborhood"]
test_x_matrix = unknown[["latitude", "longitude"]].values

model = KNN(n_neighbors = 1)
model.fit(train_x_matrix, train_y_matrix)
preds = model.predict(test_x_matrix)

unknown["neighborhood"] = preds

df.loc[unknown.index, 'neighborhood'] = pd.Series(unknown["neighborhood"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-297-21de5a4610ad> in <module>()
#       1 df["neighborhood"] = None
#       2 for i in df.index:
# ----> 3     df.set_value(i, 'neighborhood', get_region_from_latlong_and_shapefile(df['latitude'].loc[i] , df['longitude'].loc[i] , neighborhood_dict, print_errors=False))
#       4
#       5 # fill missing values using sklearn's knn functions
#
# <ipython-input-293-f588b52289fd> in get_region_from_latlong_and_shapefile(latitude, longitude, regions_to_points_dict, print_errors)
#      81 def get_region_from_latlong_and_shapefile(latitude, longitude, regions_to_points_dict, print_errors = True):
#      82     for key in regions_to_points_dict.keys():
# ---> 83         if point_inside_polygon(longitude, latitude, regions_to_points_dict[key]):
#      84             return key
#      85     if print_errors:
#
# <ipython-input-293-f588b52289fd> in point_inside_polygon(x, y, poly)
#      56     for i in range(n+1):
#      57         p2x,p2y = poly[i % n]
# ---> 58         if y > min(p1y,p2y):
#      59             if y <= max(p1y,p2y):
#      60                 if x <= max(p1x,p2x):
#
# KeyboardInterrupt:

# %%
df["schooldistrict"] = None
for i in df.index.values:
    df.set_value(i, 'schooldistrict', get_region_from_latlong_and_shapefile(df['latitude'].loc[i] , df['longitude'].loc[i] , school_district_dict, print_errors=False))

# fill missing values using sklearn's knn functions
# NOTE: manhattan only has districts 1 through 6, so we're also re-mapping everything assigned to other districts 
known = df[df["schooldistrict"] == df["schooldistrict"]]
known = df[df["schooldistrict"] < 7]
unknown = df.drop(known.index)
unknown["schooldistrict"] = None 



train_x_matrix = known[["latitude", "longitude"]].values
train_y_matrix = known["schooldistrict"].astype(int)
test_x_matrix = unknown[["latitude", "longitude"]].values

model = KNN(n_neighbors = 1)
model.fit(train_x_matrix, train_y_matrix)
preds = model.predict(test_x_matrix)

unknown["schooldistrict"] = preds

df.loc[unknown.index, 'schooldistrict'] = pd.Series(unknown["schooldistrict"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-298-6d964a4c5e7a> in <module>()
#       1 df["schooldistrict"] = None
#       2 for i in df.index.values:
# ----> 3     df.set_value(i, 'schooldistrict', get_region_from_latlong_and_shapefile(df['latitude'].loc[i] , df['longitude'].loc[i] , school_district_dict, print_errors=False))
#       4
#       5 # fill missing values using sklearn's knn functions
#
# <ipython-input-293-f588b52289fd> in get_region_from_latlong_and_shapefile(latitude, longitude, regions_to_points_dict, print_errors)
#      81 def get_region_from_latlong_and_shapefile(latitude, longitude, regions_to_points_dict, print_errors = True):
#      82     for key in regions_to_points_dict.keys():
# ---> 83         if point_inside_polygon(longitude, latitude, regions_to_points_dict[key]):
#      84             return key
#      85     if print_errors:
#
# <ipython-input-293-f588b52289fd> in point_inside_polygon(x, y, poly)
#      56     for i in range(n+1):
#      57         p2x,p2y = poly[i % n]
# ---> 58         if y > min(p1y,p2y):
#      59             if y <= max(p1y,p2y):
#      60                 if x <= max(p1x,p2x):
#
# KeyboardInterrupt:

# %%
df["precinct"] = None
for i in df.index.values:
    df.set_value(i, 'precinct', get_region_from_latlong_and_shapefile(df['latitude'].loc[i] , df['longitude'].loc[i] , precincts_dict, print_errors=False))

# %%
# fill missing values using sklearn's knn functions
# NOTE: manhattan only has districts 1-34, so we're also re-mapping everything assigned to other districts 
known = df[df["precinct"] == df["precinct"]]
known = df[df["precinct"] < 35]
unknown = df.drop(known.index)
unknown["precinct"] = None 



train_x_matrix = known[["latitude", "longitude"]].values
train_y_matrix = known["precinct"].astype(int)
test_x_matrix = unknown[["latitude", "longitude"]].values

model = KNN(n_neighbors = 1)
model.fit(train_x_matrix, train_y_matrix)
preds = model.predict(test_x_matrix)

unknown["precinct"] = preds

df.loc[unknown.index, 'precinct'] = pd.Series(unknown["precinct"])

# %%
df
# Out:
#        Unnamed: 0  tax_value  last_sold_price  property_size  \
# 0               0        NaN              NaN            NaN
# 1               1  1642000.0              NaN         2250.0
# 2               2  1674000.0              NaN         2250.0
# 3               3        NaN              NaN            NaN
# 4               4        NaN              NaN            NaN
# 5               5  2837000.0              NaN          650.0
# 6               6        NaN              NaN            NaN
# 7               7  6701000.0        3200000.0         2250.0
# 8               8  1670000.0              NaN         2250.0
# 9               9        NaN              NaN            NaN
# 10             10        NaN              NaN            NaN
# 11             11        NaN              NaN            NaN
# 12             12  1203000.0              NaN         2250.0
# 13             13        NaN              NaN            NaN
# 14             14  2837000.0              NaN         2160.0
# 15             15  2837000.0              NaN         2250.0
# 16             16        NaN              NaN            NaN
# 17             17        NaN              NaN            NaN
# 18             18  1977000.0              NaN         2250.0
# 19             19  4926000.0        1487500.0         5580.0
# 20             20        NaN           2500.0            NaN
# 21             21        NaN              NaN            NaN
# 22             22        NaN              NaN            NaN
# 23             23   842000.0              NaN         2134.0
# 24             24   791000.0              NaN         2852.0
# 25             25  5420000.0         280000.0         1197.0
# 26             26  1320000.0        2675000.0         1197.0
# 27             27  1198000.0           2500.0         2457.0
# 28             28  2159000.0         500000.0         4268.0
# 29             29        NaN            250.0            NaN
# ...           ...        ...              ...            ...
# 22766       22766  1354000.0              NaN         1584.0
# 22783                     NaN  40.825500    ...
# 22784                     NaN  40.825305    ...
# 22785                     NaN  40.825662    ...
# 22786                     NaN  40.827301    ...
# 22787                     NaN  40.825340    ...
# 22788                     NaN  40.825325    ...
# 22789                     NaN  40.825176    ...
# 22790                     NaN  40.825222    ...
# 22791                     NaN  40.825500    ...
# 22792                     NaN  40.825641    ...
# 22793                     NaN  40.825580    ...
# 22794                     NaN  40.825600    ...
# 22795                     NaN  40.826050    ...
#
#                                          graph_data_link  home_size  \
# 0                                                    NaN      400.0
# 1      http://www.zillow.com/homedetails/204-E-7th-St...    10800.0
# 2      http://www.zillow.com/homedetails/206-E-7th-St...    10800.0
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# 5      http://www.zillow.com/homedetails/216-E-7th-St...      650.0
# 6                                                    NaN        NaN
# 7      http://www.zillow.com/homedetails/222-E-7th-St...     4168.0
# 8      http://www.zillow.com/homedetails/224-E-7th-St...     8720.0
# 9                                                    NaN        NaN
# 10                                                   NaN        NaN
# 11                                                   NaN      800.0
# 12     http://www.zillow.com/homedetails/629-E-6th-St...     6985.0
# 13                                                   NaN      700.0
# 14     http://www.zillow.com/homedetails/625-E-6th-St...     6985.0
# 15     http://www.zillow.com/homedetails/623-E-6th-St...     6985.0
# 16                                                   NaN      550.0
# 17                                                   NaN      700.0
# 18     http://www.zillow.com/homedetails/613-E-6th-St...    10896.0
# 19     http://www.zillow.com/homedetails/97-Avenue-B-...     1050.0
# 20     http://www.zillow.com/homedetails/304-306-E-8t...        NaN
# 21                                                   NaN        NaN
# 22                                                   NaN        NaN
# 23     http://www.zillow.com/homedetails/330-E-8th-St...     1685.0
# 24     http://www.zillow.com/homedetails/334-E-8th-St...     1100.0
# 25     http://www.zillow.com/homedetails/113-Avenue-C...     6364.0
# 26     http://www.zillow.com/homedetails/111-Avenue-C...     3847.0
# 27     http://www.zillow.com/homedetails/107-Avenue-C...    13553.0
# 28     http://www.zillow.com/homedetails/219-E-7th-St...    18288.0
# 29     http://www.zillow.com/homedetails/209-E-7th-St...        NaN
# ...                                                  ...        ...
# 22766  http://www.zillow.com/homedetails/466-W-142nd-...     4049.0
# 22767  http://www.zillow.com/homedetails/473-W-142nd-...     3800.0
# 22768  http://www.zillow.com/homedetails/457-W-143rd-...     4192.0
# 22769  http://www.zillow.com/homedetails/320-Convent-...     5071.0
# 22770  http://www.zillow.com/homedetails/454-W-144th-...     5600.0
# 22771  http://www.zillow.com/homedetails/470-W-144th-...     5155.0
# 22772  http://www.zillow.com/homedetails/465-W-144th-...     3081.0
# 22773  http://www.zillow.com/homedetails/457-W-144th-...     4276.0
# 22774  http://www.zillow.com/homedetails/455-W-144th-...     3300.0
# 22775  http://www.zillow.com/homedetails/453-W-144th-...     4200.0
# 22776  http://www.zillow.com/homedetails/350-Convent-...     4280.0
# 22777  http://www.zillow.com/homedetails/462-W-145th-...     2541.0
# 22778                                                NaN      950.0
# 22779  http://www.zillow.com/homedetails/472-W-145th-...     4416.0
# 22780  http://www.zillow.com/homedetails/413-W-145th-...     3876.0
# 1              NaN      East Village               1         9
# 2              NaN      East Village               1         9
# 3              NaN      East Village               1         9
# 4              NaN      East Village               1         9
# 5              NaN      East Village               1         9
# 6              NaN      East Village               1         9
# 7              NaN      East Village               1         9
# 8              NaN      East Village               1         9
# 9              NaN      East Village               1         9
# 10             NaN      East Village               1         9
# 11             NaN      East Village               1         9
# 12             NaN      East Village               1         9
# 13             NaN      East Village               1         9
# 14             NaN      East Village               1         9
# 15             NaN      East Village               1         9
# 16             NaN      East Village               1         9
# 17             NaN      East Village               1         9
# 18             NaN      East Village               1         9
# 19             NaN      East Village               1         9
# 20             NaN      East Village               1         9
# 21             NaN        Park Slope               1         7
# 22             NaN      East Village               1         9
# 23             NaN      East Village               1         9
# 24             NaN      Borough Park               1         7
# 25             NaN      East Village               1         9
# 26             NaN      East Village               1         9
# 27             NaN      East Village               1         9
# 28             NaN      East Village               1         9
# 29             NaN      East Village               1         9
# ...            ...               ...             ...       ...
# 22766          NaN  Hamilton Heights               6        30
# 22767          NaN  Hamilton Heights               6        30
# 22768          NaN  Hamilton Heights               6        30
# 22769          NaN  Hamilton Heights               6        30
# 22770          NaN  Hamilton Heights               6        30
# 22771          NaN  Hamilton Heights               6        30
# 22772          NaN  Hamilton Heights               6        30
# 22773          NaN  Hamilton Heights               6        30
# 22774          NaN  Hamilton Heights               6        30
# 22775          NaN  Hamilton Heights               6        30
# 22776          NaN  Hamilton Heights               6        30
# 22777          NaN  Hamilton Heights               6        30
# 22778          NaN  Hamilton Heights               6        30
# 22779          NaN  Hamilton Heights               6        30
# 22780          NaN  Hamilton Heights               6        30
# 22781          NaN            Harlem               5        30
# 22782          NaN  Hamilton Heights               6        30
# 22783          NaN  Hamilton Heights               6        30
# 22784          NaN  Hamilton Heights               6        30
# 22785          NaN  Hamilton Heights               6        30
# 22786          NaN  Hamilton Heights               6        30
# 22787          NaN  Hamilton Heights               6        30
# 22788          NaN  Hamilton Heights               6        30
# 22789          NaN  Hamilton Heights               6        30
# 22790          NaN  Hamilton Heights               6        30
# 22791          NaN  Hamilton Heights               6        30
# 22792          NaN  Hamilton Heights               6        30
# 22793          NaN  Hamilton Heights               6        30
# 22794          NaN  Hamilton Heights               6        30
# 22795          NaN  Hamilton Heights               6        30
#
# [22792 rows x 27 columns]

# %%
#write data to file before we add demographic stuff
df.to_csv("mn_with_regions.csv")

# %%
df = pd.read_csv("mn_with_regions.csv")

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  tax_value  last_sold_price  property_size  \
# 0               0             0        NaN              NaN            NaN
# 1               1             1  1642000.0              NaN         2250.0
# 2               2             2  1674000.0              NaN         2250.0
# 3               3             3        NaN              NaN            NaN
# 4               4             4        NaN              NaN            NaN
# 5               5             5  2837000.0              NaN          650.0
# 6               6             6        NaN              NaN            NaN
# 7               7             7  6701000.0        3200000.0         2250.0
# 8               8             8  1670000.0              NaN         2250.0
# 9               9             9        NaN              NaN            NaN
# 10             10            10        NaN              NaN            NaN
# 11             11            11        NaN              NaN            NaN
# 12             12            12  1203000.0              NaN         2250.0
# 13             13            13        NaN              NaN            NaN
# 14             14            14  2837000.0              NaN         2160.0
# 15             15            15  2837000.0              NaN         2250.0
# 16             16            16        NaN              NaN            NaN
# 17             17            17        NaN              NaN            NaN
# 18             18            18  1977000.0              NaN         2250.0
# 19             19            19  4926000.0        1487500.0         5580.0
# 20             20            20        NaN           2500.0            NaN
# 21             21            21        NaN              NaN            NaN
# 22             22            22        NaN              NaN            NaN
# 23             23            23   842000.0              NaN         2134.0
# 24             24            24   791000.0              NaN         2852.0
# 25             25            25  5420000.0         280000.0         1197.0
# 26             26            26  1320000.0        2675000.0         1197.0
# 27             27            27  1198000.0           2500.0         2457.0
# 28             28            28  2159000.0         500000.0         4268.0
# 29             29            29        NaN            250.0            NaN
# ...           ...           ...        ...              ...            ...
# 22762       22766         22766  1354000.0              NaN         1584.0
# 22763       22767         22767  1649000.0              NaN         1881.0
# 22764       22768         22768  1992000.0        1700000.0         1782.0
# 22765       22769         22769  2612000.0        3890000.0         1900.0
# 22766       22770         22770  2219000.0              NaN         1980.0
# 22767       22771         22771  2125000.0              NaN         1683.0
# 22768       22772         22772  1511000.0              NaN         1584.0
# 22769       22773         22773  2184000.0              NaN         1584.0
# 22770       22774         22774  1643000.0              NaN         1980.0
# 22771       22775         22775  1799000.0              NaN         2079.0
# 22772       22776         22776  1686000.0        1975000.0         1880.0
# 22773       22777         22777   343000.0              NaN         1584.0
# 22774       22778         22778        NaN              NaN            NaN
# 22775       22779         22779  1504000.0              NaN         1584.0
# 22776       22780         22780  1452000.0        1450000.0         1881.0
# 22777       22781         22781        NaN              NaN            NaN
# 22778       22782         22782        NaN              NaN            NaN
# 22779       22783         22783        NaN              NaN            NaN
# 22780       22784         22784   648000.0              NaN         1999.0
# 22781       22785         22785  1669000.0        2455000.0         1584.0
# 22782       22786         22786        NaN              NaN            NaN
# 22783       22787         22787   305000.0         175000.0         1186.0
# 22784       22788         22788        NaN              NaN            NaN
# 22785       22789         22789        NaN              NaN            NaN
# 22786       22790         22790  2125000.0         436500.0         1672.0
# 22787       22791         22791  1381000.0        2890000.0         1980.0
# 22788       22792         22792        NaN              NaN            NaN
# 22789       22793         22793  1409000.0         365000.0         1881.0
# 22790       22794         22794        NaN              NaN            NaN
# 22791       22795         22795        NaN              NaN            NaN
#
#        zestimate_amount  bathrooms  zestimate_valuation_range_high  tax_year  \
# 0              849427.0        1.0                       1044795.0       NaN
# 1                   NaN        2.0                             NaN    2015.0
# 2             7332356.0        1.0                       7992268.0    2015.0
# 3             1991289.0        1.0                       2708153.0       NaN
# 4                   NaN        NaN                             NaN       NaN
# 5             1225236.0        1.0                       1298750.0    2015.0
# 6                   NaN        1.0                             NaN       NaN
# 7            12785150.0        NaN                      13807962.0    2015.0
# 8             7615912.0        1.0                       9215254.0    2015.0
# 9             4106754.0        1.0                       4640632.0       NaN
# 10            1417455.0        1.0                       1573375.0       NaN
# 11            1662365.0        1.0                       1944967.0       NaN
# 12            9138381.0        NaN                       9595300.0    2007.0
# 13            1226265.0        1.0                       1361154.0       NaN
# 14           10171986.0        NaN                      11290905.0    2015.0
# 15            9319621.0        NaN                       9785602.0    2015.0
# 16             763214.0        1.0                        900593.0       NaN
# 17            1091932.0        1.0                       1201125.0       NaN
# 18            9368589.0        1.5                      10211762.0    2015.0
# 19            3396486.0        NaN                       4687151.0    2015.0
# 20            1395607.0        NaN                       1590992.0       NaN
# 21             883453.0        1.0                        927626.0       NaN
# 22            1336108.0        1.0                       1509802.0       NaN
# 23            2916283.0        1.0                       3470377.0    2007.0
# 24                  NaN        1.0                             NaN    2015.0
# 25           10359737.0        NaN                      11913698.0    2015.0
# 26            7503575.0        NaN                       7878754.0    2007.0
# 27            9955544.0        NaN                      10552877.0    2015.0
# 28           14277813.0        1.0                      14991704.0    2015.0
# 29             955649.0        NaN                       1156335.0       NaN
# ...                 ...        ...                             ...       ...
# 22762         2976171.0        NaN                       3273788.0    2015.0
# 22763         1523440.0        1.0                       2513676.0    2015.0
# 22764         3762393.0        4.0                       4176256.0    2015.0
# 22765         4761166.0        NaN                       5618176.0    2015.0
# 22766         4240170.0        NaN                       5469819.0    2015.0
# 22767         3547684.0        NaN                       4079837.0    2015.0
# 22768         3094499.0        NaN                       3558674.0    2015.0
# 22769         3878528.0        NaN                       5119657.0    2015.0
# 22770         3434251.0        NaN                       3846361.0    2015.0
# 22771         3335298.0        4.0                       3768887.0    2015.0
# 22772         3250179.0        NaN                       3737706.0    2015.0
# 22773         4990351.0        NaN                       5589193.0    2007.0
# 22774         1013025.0        1.0                       1144718.0       NaN
# 22775         1222924.0        4.5                       1406363.0    2015.0
# 22776         3996486.0        NaN                       4595959.0    2015.0
# 22777          523737.0        1.0                        618010.0       NaN
# 22778         5588310.0        1.0                       6426556.0       NaN
# 22779         2095633.0        1.0                       2451891.0       NaN
# 22780         2908804.0        4.0                       3461477.0    2015.0
# 22781         3446501.0        7.0                       3825616.0    2015.0
# 22782          785315.0        1.0                        879553.0       NaN
# 22783         2217756.0        1.0                       2750017.0    2015.0
# 22784         1504090.0        1.0                       1804908.0       NaN
# 22785               NaN        NaN                             NaN       NaN
# 22786         1697922.0        1.0                       3124176.0    2015.0
# 22787         3163172.0        4.5                       3384594.0    2015.0
# 22788               NaN        1.0                             NaN       NaN
# 22789         3290698.0        NaN                       3817210.0    2015.0
# 22790         4584334.0        NaN                       4905237.0       NaN
# 22791         3432030.0        1.5                       4049795.0       NaN
#
#        zestimate_value_change    ...     \
# 0                         NaN    ...
# 1                         NaN    ...
# 2                         NaN    ...
# 3                         NaN    ...
# 4                         NaN    ...
# 5                         NaN    ...
# 6                         NaN    ...
# 7                         NaN    ...
# 8                         NaN    ...
# 9                         NaN    ...
# 10                        NaN    ...
# 11                        NaN    ...
# 12                        NaN    ...
# 13                        NaN    ...
# 14                        NaN    ...
# 15                        NaN    ...
# 16                        NaN    ...
# 17                        NaN    ...
# 18                        NaN    ...
# 19                        NaN    ...
# 20                        NaN    ...
# 21                        NaN    ...
# 22                        NaN    ...
# 23                        NaN    ...
# 24                        NaN    ...
# 25                        NaN    ...
# 26                        NaN    ...
# 27                        NaN    ...
# 28                        NaN    ...
# 29                        NaN    ...
# ...                       ...    ...
# 22762                     NaN    ...
# 22763                     NaN    ...
# 22764                     NaN    ...
# 22765                     NaN    ...
# 22766                     NaN    ...
# 22767                     NaN    ...
# 22768                     NaN    ...
# 22769                     NaN    ...
# 22770                     NaN    ...
# 22771                     NaN    ...
# 22772                     NaN    ...
# 22773                     NaN    ...
# 22774                     NaN    ...
# 22775                     NaN    ...
# 22776                     NaN    ...
# 22777                     NaN    ...
# 22778                     NaN    ...
# 22779                     NaN    ...
# 22780                     NaN    ...
# 22781                     NaN    ...
# 22782                     NaN    ...
# 22783                     NaN    ...
# 22784                     NaN    ...
# 22785                     NaN    ...
# 22786                     NaN    ...
# 22787                     NaN    ...
# 22788                     NaN    ...
# 22789                     NaN    ...
# 22790                     NaN    ...
# 22791                     NaN    ...
#
#                                          graph_data_link  home_size  \
# 0                                                    NaN      400.0
# 1      http://www.zillow.com/homedetails/204-E-7th-St...    10800.0
# 2      http://www.zillow.com/homedetails/206-E-7th-St...    10800.0
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# 5      http://www.zillow.com/homedetails/216-E-7th-St...      650.0
# 6                                                    NaN        NaN
# 7      http://www.zillow.com/homedetails/222-E-7th-St...     4168.0
# 8      http://www.zillow.com/homedetails/224-E-7th-St...     8720.0
# 9                                                    NaN        NaN
# 10                                                   NaN        NaN
# 11                                                   NaN      800.0
# 12     http://www.zillow.com/homedetails/629-E-6th-St...     6985.0
# 13                                                   NaN      700.0
# 14     http://www.zillow.com/homedetails/625-E-6th-St...     6985.0
# 15     http://www.zillow.com/homedetails/623-E-6th-St...     6985.0
# 16                                                   NaN      550.0
# 17                                                   NaN      700.0
# 18     http://www.zillow.com/homedetails/613-E-6th-St...    10896.0
# 19     http://www.zillow.com/homedetails/97-Avenue-B-...     1050.0
# 20     http://www.zillow.com/homedetails/304-306-E-8t...        NaN
# 21                                                   NaN        NaN
# 22                                                   NaN        NaN
# 23     http://www.zillow.com/homedetails/330-E-8th-St...     1685.0
# 24     http://www.zillow.com/homedetails/334-E-8th-St...     1100.0
# 25     http://www.zillow.com/homedetails/113-Avenue-C...     6364.0
# 26     http://www.zillow.com/homedetails/111-Avenue-C...     3847.0
# 27     http://www.zillow.com/homedetails/107-Avenue-C...    13553.0
# 28     http://www.zillow.com/homedetails/219-E-7th-St...    18288.0
# 29     http://www.zillow.com/homedetails/209-E-7th-St...        NaN
# ...                                                  ...        ...
# 22762  http://www.zillow.com/homedetails/466-W-142nd-...     4049.0
# 22763  http://www.zillow.com/homedetails/473-W-142nd-...     3800.0
# 22764  http://www.zillow.com/homedetails/457-W-143rd-...     4192.0
# 22765  http://www.zillow.com/homedetails/320-Convent-...     5071.0
# 22766  http://www.zillow.com/homedetails/454-W-144th-...     5600.0
# 22767  http://www.zillow.com/homedetails/470-W-144th-...     5155.0
# 22768  http://www.zillow.com/homedetails/465-W-144th-...     3081.0
# 22769  http://www.zillow.com/homedetails/457-W-144th-...     4276.0
# 22788        Apartment  http://www.zillow.com/homes/2108072329_zpid/
# 22789     SingleFamily    http://www.zillow.com/homes/31552971_zpid/
# 22790        Townhouse  http://www.zillow.com/homes/2108249496_zpid/
# 22791  MultiFamily2To4  http://www.zillow.com/homes/2102141184_zpid/
#
#        Unnamed: 22      neighborhood schooldistrict  precinct
# 0              NaN      East Village              1         9
# 1              NaN      East Village              1         9
# 2              NaN      East Village              1         9
# 3              NaN      East Village              1         9
# 4              NaN      East Village              1         9
# 5              NaN      East Village              1         9
# 6              NaN      East Village              1         9
# 7              NaN      East Village              1         9
# 8              NaN      East Village              1         9
# 9              NaN      East Village              1         9
# 10             NaN      East Village              1         9
# 11             NaN      East Village              1         9
# 12             NaN      East Village              1         9
# 13             NaN      East Village              1         9
# 14             NaN      East Village              1         9
# 15             NaN      East Village              1         9
# 16             NaN      East Village              1         9
# 17             NaN      East Village              1         9
# 18             NaN      East Village              1         9
# 19             NaN      East Village              1         9
# 20             NaN      East Village              1         9
# 21             NaN        Park Slope              1         7
# 22             NaN      East Village              1         9
# 23             NaN      East Village              1         9
# 24             NaN      Borough Park              1         7
# 25             NaN      East Village              1         9
# 26             NaN      East Village              1         9
# 27             NaN      East Village              1         9
# 28             NaN      East Village              1         9
# 29             NaN      East Village              1         9
# ...            ...               ...            ...       ...
# 22762          NaN  Hamilton Heights              6        30
# 22763          NaN  Hamilton Heights              6        30
# 22764          NaN  Hamilton Heights              6        30
# 22765          NaN  Hamilton Heights              6        30
# 22766          NaN  Hamilton Heights              6        30
# 22767          NaN  Hamilton Heights              6        30
# 22768          NaN  Hamilton Heights              6        30
# 22769          NaN  Hamilton Heights              6        30
# 22770          NaN  Hamilton Heights              6        30
# 22771          NaN  Hamilton Heights              6        30
# 22772          NaN  Hamilton Heights              6        30
# 22773          NaN  Hamilton Heights              6        30
# 22774          NaN  Hamilton Heights              6        30
# 22775          NaN  Hamilton Heights              6        30
# 22776          NaN  Hamilton Heights              6        30
# 22777          NaN            Harlem              5        30
# 22778          NaN  Hamilton Heights              6        30
# 22779          NaN  Hamilton Heights              6        30
# 22780          NaN  Hamilton Heights              6        30
# 22781          NaN  Hamilton Heights              6        30
# 22782          NaN  Hamilton Heights              6        30
# 22783          NaN  Hamilton Heights              6        30
# 22784          NaN  Hamilton Heights              6        30
# 22785          NaN  Hamilton Heights              6        30
# 22786          NaN  Hamilton Heights              6        30
# 22787          NaN  Hamilton Heights              6        30
# 22788          NaN  Hamilton Heights              6        30
# 22789          NaN  Hamilton Heights              6        30
# 22790          NaN  Hamilton Heights              6        30
# 22791          NaN  Hamilton Heights              6        30
#
# [22792 rows x 28 columns]

# %% [markdown]
# # Merge in data about precincts/school districts

# %% [markdown]
# ## Precincts:

# %%
path_to_crime_files = "/Users/nbw/Dropbox/CS_109_Project/crime_dfs/"

# %%
crime_files = os.listdir(path_to_crime_files)

# %%
for filename in os.listdir(path_to_crime_files)[1:]:
    crime = filename.split("(")[0].split(".csv")[0].strip()
    crime_df = pd.read_csv(path_to_crime_files+filename)

    crime_df.rename(columns={'last_3_years': crime+"_last_3_years", 'percent_change': crime+"_percent_change"}, inplace=True)

    merged = df.merge(crime_df, how="outer", left_on="precinct", right_on="PCT")
    merged = merged[merged["precinct"] == merged["precinct"]]
    merged = merged.drop("PCT",axis=1)
    if len(merged) != len(df):
        print "something weird! " + filename
    df = merged

# %%
# write a file containing just crime data
df.to_csv("mn_crimes_only.csv")

# %% [markdown]
# ## School Districts

# %%
schools = pd.read_csv('/Users/nbw/Dropbox/CS_109_Project/test_scores/nyctestscores.csv')

# %%
schools = schools.drop(["Grade", "Year", "Category"],axis=1)

# %%
for colname in schools.columns:
    schools.rename(columns={colname: "schools_" + colname}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  tax_value  last_sold_price  property_size  \
# 0           0             0        NaN              NaN            NaN
# 1           1             1  1642000.0              NaN         2250.0
# 2           2             2  1674000.0              NaN         2250.0
# 3           3             3        NaN              NaN            NaN
# 4           4             4        NaN              NaN            NaN
#
#    zestimate_amount  bathrooms  zestimate_valuation_range_high  tax_year  \
# 0          849427.0        1.0                       1044795.0       NaN
# 1               NaN        2.0                             NaN    2015.0
# 2         7332356.0        1.0                       7992268.0    2015.0
# 3         1991289.0        1.0                       2708153.0       NaN
# 4               NaN        NaN                             NaN       NaN
#
#    zestimate_value_change    ...     \
# 0                     NaN    ...
# 1                     NaN    ...
# 2                     NaN    ...
# 3                     NaN    ...
# 4                     NaN    ...
#
#                                      graph_data_link  home_size  longitude  \
# 0                                                NaN      400.0 -73.980284
# 1  http://www.zillow.com/homedetails/204-E-7th-St...    10800.0 -73.980200
# 2  http://www.zillow.com/homedetails/206-E-7th-St...    10800.0 -73.980120
# 3                                                NaN        NaN -73.980007
# 4                                                NaN        NaN -73.980804
#
#                                     home_detail_link        home_type  \
# 0  http://www.zillow.com/homedetails/202-E-7th-St...  MultiFamily2To4
# 1  http://www.zillow.com/homedetails/204-E-7th-St...        Apartment
# 2  http://www.zillow.com/homedetails/206-E-7th-St...      Cooperative
# 3  http://www.zillow.com/homedetails/208-E-7th-St...  MultiFamily2To4
# 4  http://www.zillow.com/homedetails/190-E-7th-St...          Unknown
#
#                              map_this_home_link  Unnamed: 22  neighborhood  \
# 0  http://www.zillow.com/homes/2098748189_zpid/          NaN  East Village
# 1    http://www.zillow.com/homes/31495862_zpid/          NaN  East Village
# 2    http://www.zillow.com/homes/31495863_zpid/          NaN  East Village
# 3  http://www.zillow.com/homes/2098632095_zpid/          NaN  East Village
# 4  http://www.zillow.com/homes/2131860614_zpid/          NaN  East Village
#
#   schooldistrict  precinct
# 0              1         9
# 1              1         9
# 2              1         9
# 3              1         9
# 4              1         9
#
# [5 rows x 28 columns]

# %%
merged = df.merge(schools, how="outer", left_on="schooldistrict", right_on="schools_district")
merged = merged[merged["schooldistrict"] == merged["schooldistrict"]]
merged = merged.drop("schools_district",axis=1)
if len(merged) != len(df):
    print "something weird! " + filename

df = merged

# %%
# if we want just schools, dont run "Precincts:" block
# write a file containing just crime data
df.to_csv("mn_schools_only.csv")

# %%
# Write data
df.to_csv("mn_crimes_and_schools.csv")
