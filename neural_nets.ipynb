# %%
# ONLY USE THIS BLOCK OF CODE ON NICASIA'S COMPUTER 
import sys
sys.path.append("/anaconda/lib/python2.7/site-packages")
#####



import numpy as np 
import pandas as pd 
import os

# %%
data = pd.read_csv("mn_crimes_and_schools.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1  tax_value  last_sold_price  \
# 0           0           0.0           0.0        NaN              NaN
# 1           1           1.0           1.0  1642000.0              NaN
# 2           2           2.0           2.0  1674000.0              NaN
# 3           3           3.0           3.0        NaN              NaN
# 4           4           4.0           4.0        NaN              NaN
#
#    property_size  zestimate_amount  bathrooms  zestimate_valuation_range_high  \
# 0            NaN          849427.0        1.0                       1044795.0
# 1         2250.0               NaN        2.0                             NaN
# 2         2250.0         7332356.0        1.0                       7992268.0
# 3            NaN         1991289.0        1.0                       2708153.0
# 4            NaN               NaN        NaN                             NaN
#
#    tax_year                   ...                    \
# ...

# %%
data = data.drop([u'Unnamed: 0', u'Unnamed: 0.1', u'Unnamed: 0.1'], axis=1)
data.to_csv("test", index=False)

# %%
pd.read_csv("test")
# Out:
#        tax_value  last_sold_price  property_size  zestimate_amount  bathrooms  \
# 0            NaN              NaN            NaN          849427.0        1.0
# 1      1642000.0              NaN         2250.0               NaN        2.0
# 2      1674000.0              NaN         2250.0         7332356.0        1.0
# 3            NaN              NaN            NaN         1991289.0        1.0
# 4            NaN              NaN            NaN               NaN        NaN
# 5      2837000.0              NaN          650.0         1225236.0        1.0
# 6            NaN              NaN            NaN               NaN        1.0
# 7      6701000.0        3200000.0         2250.0        12785150.0        NaN
# 8      1670000.0              NaN         2250.0         7615912.0        1.0
# 9            NaN              NaN            NaN         4106754.0        1.0
# 10           NaN              NaN            NaN         1417455.0        1.0
# ...
